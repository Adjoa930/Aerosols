# %%
#import libraries

import xarray as xr
import matplotlib.pyplot as plt

# %%
#in this method i used cdo to compute the trend, season and residuals and imported the datasets into python xarray
#read the datasets
WA= xr.open_dataset('West_Afrique_tm.nc')
s = xr.open_dataset('season1.nc')
trend = xr.open_dataset('a.nc')
residual = xr.open_dataset('new1.nc')
s1 = s['AOD_550_Dark_Target_Deep_Blue_Combined_Mean_Mean']
#ds1 = ds['AOD_550_Dark_Target_Deep_Blue_Combined_Mean_Mean']
trend1 = trend['AOD_550_Dark_Target_Deep_Blue_Combined_Mean_Mean']
residual1 = residual['AOD_550_Dark_Target_Deep_Blue_Combined_Mean_Mean']
WA1 = WA['AOD_550_Dark_Target_Deep_Blue_Combined_Mean_Mean']

# %%
#Plotting
t= trend1.mean(dim='lat')
#plt.title('trend')
r= residual1.mean(dim='lat')
#plt.title('residuals')
s= s1.mean(dim = 'lat')
#plt.title('seasonal')
w = WA1.mean(dim = 'lat')
#plt.title('original')

# %%
fig = plt.figure(figsize=(12,10))

t.plot(label = 'trend')
r.plot(label = 'residual')
s.plot(label = 'seasonal')
w.plot(label = 'original')
plt.legend(loc='best')
plt.title('plots')
# Out:
# Text(0.5, 1.0, 'plots')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-746126b53adf> in <module>
# ----> 1 plt.scatter(WA1,1)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2814         verts=verts, edgecolors=edgecolors,
#    2815         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2816         None else {}), **kwargs)
#    2817     sci(__ret)
#    2818     return __ret
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...
